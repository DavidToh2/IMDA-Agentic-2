# %%
from PIL import Image
import pytesseract

# %%
image = Image.open('test.png')
text = pytesseract.image_to_string( image )
print(text)
# Out:
# (ea WIKIPEDIA Q_ Search Wikipedia Search
#
# ag The Free Encyclopedia
# iM ac G3 3% 14languages v
# Contents hide Article Talk Read Viewsource Viewhistory Tools v
# (Top) From Wikipedia, the free encyclopedia * A
# Background
# 5 The iMac G3, originally released as the iMac, is a series of iMac G3
# S| .
#
# esign Macintosh personal computers that Apple Computer sold 5
# Rel
#
# srease ; from 1998 to 2003. The iMac was Apple's first major product
#
# Model line-up release under CEO Sieve Jobs following his return to the at
# Reception financially troubled company he co-founded. Jobs
#
# Sales reorganized the company and simplified the product line.
# Legacy The iMac was designed as Apple's new consumer desktop
# Specifications
#
# First generation
#
# Second generation
# References
#
# Sources
#
# External links
#
# product—an inexpensive, consumer-oriented computer that
# would easily connect to the Internet.
#
# The iMac's all-in-one design is based around a cathode-ray
# ...
